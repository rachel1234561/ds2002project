# %% [markdown]
# <a href="https://colab.research.google.com/github/rachel1234561/ds2002project/blob/main/analysis_vizulizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **The first section is visualizations/EDA for the college scorecard data, the seccod is visualizations/EDA for the American Community survey data, and the final section is our analysis which combines both data sets to explore how income is are affected weather or not someone graduates college by state.**

# %% [markdown]
# ### College Scorecard Vizulizations

# %%
import pandas as pd

# %%
# !git clone https://github.com/rachel1234561/ds2002project.git
# Out:
# Cloning into 'ds2002project'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), 128.11 KiB | 1001.00 KiB/s, done.

# %%
data = pd.read_csv('/content/ds2002project/college_data_clean.csv')

# %%
if 'degree_type' in data.columns:
  data = data.drop('degree_type', axis=1)

# %%
variables = data.columns.tolist()
variables
# Out:
# ['id',
#  'name',
#  'zip',
#  'city',
#  'state',
#  'acceptance_rate',
#  'part_time',
#  'debt',
#  'pell_grant',
#  'stud_fac_ratio',
#  'percent_loans',
#  'graduation_rate',
#  'yearly_cost',
#  'student_pop',
#  'earnings',
#  'school_type',
#  'region',
#  'average_act',
#  'precent_female',
#  'average_income']

# %%
# Import Matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(8, 5))
plt.hist(data['yearly_cost'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of yearly costs')
plt.xlabel('yearly costs')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.hist(data['earnings'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of earnings costs')
plt.xlabel('earnings')
plt.ylabel('Frequency')
plt.show()

# %%
# Create a scatter plot using Matplotlib
#this vizulization can help think through the question of if the cost of college is worth it
data['yearly_cost'] = pd.to_numeric(data['yearly_cost'], errors='coerce')
data['earnings'] = pd.to_numeric(data['earnings'], errors='coerce')
plt.figure(figsize=(10, 6))
plt.scatter(data['yearly_cost'], data['earnings'])
plt.title('Scatter Plot of yearly cost vs. Average Student Earnings following Graduation')
plt.xlabel('Pell Grant')
plt.ylabel('Earnings')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Compute the correlation matrix using only numeric columns
numeric_vars = data.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_vars.corr()

# Create a heatmap
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Seaborn Heatmap of Numeric Features in College Dataset')
plt.show()

# %%
# Create a box plot using Seaborn
plt.figure(figsize=(10, 6))
sns.boxplot(x='state', y='earnings', data=data)
plt.title('Box Plot of Average Earnings of graduates by State')
plt.xlabel('State')
plt.ylabel('Average Earnings')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()
#this could be interesting to compate to earnings by state overall

# %% [markdown]
# ## American Community Suevery
