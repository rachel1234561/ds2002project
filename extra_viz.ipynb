# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('college_data_clean.csv')
data=data.drop('degree_type',axis=1)
variables = data.columns.tolist()

# %%
plt.figure(figsize=(8, 5))
plt.hist(data['yearly_cost'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of yearly costs')
plt.xlabel('yearly costs')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.hist(data['earnings'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of earnings')
plt.xlabel('earnings')
plt.ylabel('Frequency')
plt.show()

# %%
earnings_edu = pd.read_csv("state_earnings.csv")
earnings_edu.set_index('State', inplace=True)

# %%
y=list(earnings_edu['Less_than_highschool'])
x=list(earnings_edu.index)
plt.bar(x,y,width=.8,color='purple') 
plt.xticks(rotation=90)
plt.ylabel('Earnings')
plt.xlabel('State')
plt.title('Less than High School Earnings')
plt.tick_params(axis='x', which='major', labelsize=8)
plt.show()

# %%
y=list(earnings_edu['Highschool'])
x=list(earnings_edu.index)
plt.bar(x,y,width=.8,color='orange') 
plt.xticks(rotation=90)
plt.ylabel('Earnings')
plt.xlabel('State')
plt.title('High School Earnings')
plt.tick_params(axis='x', which='major', labelsize=8)
plt.show()

# %%
y=list(earnings_edu['Bachelors'])
x=list(earnings_edu.index)
plt.bar(x,y,width=.8,color='green') 
plt.xticks(rotation=90)
plt.ylabel('Earnings')
plt.xlabel('State')
plt.title('Bachelors Earnings')
plt.tick_params(axis='x', which='major', labelsize=8)
plt.show()

# %%
y=list(earnings_edu['Some_college_Associates'])
x=list(earnings_edu.index)
plt.bar(x,y,width=.8,color='red') 
plt.xticks(rotation=90)
plt.ylabel('Earnings')
plt.xlabel('State')
plt.title('Some College Earnings')
plt.tick_params(axis='x', which='major', labelsize=8)
plt.show()

# %%
y=list(earnings_edu['Graduates_Professional'])
x=list(earnings_edu.index)
plt.bar(x,y,width=.8,color='blue') 
plt.ylabel('Earnings')
plt.xlabel('State')
plt.title('Graduates Earnings')
plt.tick_params(axis='x', which='major', labelsize=8)
plt.xticks(rotation=90)
plt.show()
